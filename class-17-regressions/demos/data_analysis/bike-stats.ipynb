# %% [markdown]
# # Bicycle Stuff
# ## JB Tellez
# ### 3/11/19

# %%
import pandas as pd
import numpy

# %%
trip_frame = pd.read_csv('trip.csv', error_bad_lines=False)
trip_frame[:3]
# Out:
# b'Skipping line 50794: expected 12 fields, saw 20\n'
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender  birthyear
# 0          CBD-06         PS-04   Member    Male     1960.0
# 1          CBD-06         PS-04   Member    Male     1970.0
# 2          CBD-06         PS-04   Member  Female     1988.0

# %%
station_frame = pd.read_csv('station.csv')
modified_stations = station_frame[pd.notnull(station_frame['modification_date'])]
modified_stations
# Out:
#    station_id                                               name        lat  \
# 7      CBD-06                                2nd Ave & Spring St  47.605950
# 10      CD-01                            12th Ave & E Yesler Way  47.602103
# 12      CH-02                     E Harrison St & Broadway Ave E  47.622063
# 17      CH-08             Cal Anderson Park / 11th Ave & Pine St  47.615486
# 22     DPD-03  Children's Hospital / Sandpoint Way NE & 40th ...  47.663509
# 23      EL-01  Fred Hutchinson Cancer Research Center / Fairv...  47.627643
# 26      FH-01          Frye Art Museum / Terry Ave & Columbia St  47.607281
# 31     SLU-01                         REI / Yale Ave N & John St  47.619859
# 35     SLU-15                             Westlake Ave & 6th Ave  47.613628
# 37     SLU-17          Lake Union Park / Valley St & Boren Ave N  47.626041
# 38     SLU-18                             Dexter Ave & Denny Way  47.618285
# ...

# %%
weather_frame = pd.read_csv('weather.csv')
weather_frame[:3]
# Out:
#          Date  Max_Temperature_F  Mean_Temperature_F  Min_TemperatureF  \
# 0  10/13/2014                 71                62.0                54
# 1  10/14/2014                 63                59.0                55
# 2  10/15/2014                 62                58.0                54
#
#    Max_Dew_Point_F  MeanDew_Point_F  Min_Dewpoint_F  Max_Humidity  \
# 0               55               51              46            87
# 1               52               51              50            88
# 2               53               50              46            87
#
#    Mean_Humidity  Min_Humidity  ...  Mean_Sea_Level_Pressure_In  \
# 0             68            46  ...                       29.79
# 1             78            63  ...                       29.75
# 2             77            67  ...                       29.71
#
#    Min_Sea_Level_Pressure_In  Max_Visibility_Miles  Mean_Visibility_Miles  \
# 0                      29.65                    10                     10
# ...

# %%
avg_trip_duration = trip_frame.tripduration.mean()
avg_trip_duration
# Out:
# 1178.2956753399776

# %%
most_common_birth_year = trip_frame.birthyear.mode()
most_common_birth_year
most_common_age = int(2019 - most_common_birth_year)

# %%
print(f'most common age is {most_common_age} years old')
# Out:
# most common age is 32 years old

# %%
avg_precipitation = weather_frame.Precipitation_In.mean()
avg_precipitation
# Out:
# 0.10506531204644412
