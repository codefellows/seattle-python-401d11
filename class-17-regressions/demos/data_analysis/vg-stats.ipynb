# %%
import pandas as pd

# %%
games_frame = pd.read_csv('vgsales.csv')

# %%
games_frame[:5]
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
games_frame['EU_Sales'].mean()
# Out:
# 0.14665200626581515

# %%
games_frame[:10]['Name']
# Out:
# 0                   Wii Sports
# 1            Super Mario Bros.
# 2               Mario Kart Wii
# 3            Wii Sports Resort
# 4     Pokemon Red/Pokemon Blue
# 5                       Tetris
# 6        New Super Mario Bros.
# 7                     Wii Play
# 8    New Super Mario Bros. Wii
# 9                    Duck Hunt
# Name: Name, dtype: object

# %%
jp_gold = games_frame[games_frame['JP_Sales'] > 5][['Name','JP_Sales']]
jp_gold
# Out:
#                                            Name  JP_Sales
# 1                             Super Mario Bros.      6.81
# 4                      Pokemon Red/Pokemon Blue     10.22
# 6                         New Super Mario Bros.      6.50
# 12                  Pokemon Gold/Pokemon Silver      7.20
# 20                Pokemon Diamond/Pokemon Pearl      6.04
# 25                Pokemon Ruby/Pokemon Sapphire      5.38
# 26                  Pokemon Black/Pokemon White      5.65
# 27  Brain Age 2: More Training in Minutes a Day      5.32
# 41                  Animal Crossing: Wild World      5.33

# %%
na_median = games_frame['NA_Sales'].median()
games_frame[games_frame.NA_Sales == na_median][:10]
# Out:
#       Rank                                               Name Platform  \
# 446    447                                  Dragon Warrior IV      NES
# 497    498        World Soccer Winning Eleven 7 International      PS2
# 1617  1619                             Farming Simulator 2015       PC
# 1926  1928                          Pro Evolution Soccer 2008     X360
# 2067  2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# 2373  2375                           Phantasy Star Portable 2      PSP
# 2579  2581                               The Sims 2: Castaway      PSP
# 3186  3188                                     SingStar Queen      PS2
# 3503  3505                                         Top Spin 3      PS3
# 3703  3705               Sonic & All-Stars Racing Transformed      PS3
#
#         Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 446   1990.0  Role-Playing              Enix Corporation      0.08      0.00
# ...
